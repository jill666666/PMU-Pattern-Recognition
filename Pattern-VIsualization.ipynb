# %% [markdown]
# # Voltage and Frequency Data Visualization

# %%
from __future__ import print_function
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import coremltools
from scipy import stats
from IPython.display import display, HTML

from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils

import os

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# Set some standard parameters upfront
pd.options.display.float_format = '{:.1f}'.format
sns.set() # Default seaborn look and feel
plt.style.use('ggplot')
print('keras version ', keras.__version__)
# Same labels will be reused throughout the program
LABELS = ['branch_trip',
          'gen_loss',]
# The number of steps within one time segment
TIME_PERIODS = 80
# The steps to take from one segment to the next; if this value is equal to
# TIME_PERIODS, then there is no overlap between the segments
STEP_DISTANCE = 40
# Out:
# keras version  2.2.4

# %%
def convert_to_float(x):

    try:
        return np.float(x)
    except:
        return np.nan

# %%
# Load data set containing all the data from csv
column_names = ['timestamp',
                    'voltage',
                    'frequency']

migeum = pd.read_csv('/Users/jill/Desktop/coreml.csv',
                header = None,
                names = column_names)    
plt.figure(1)
plt.subplots(figsize=(8, 3))
plt.plot(migeum['voltage'][:1000], 'g')
plt.title('migeum_line_fault')
plt.xlabel('timestamp')
plt.ylabel('voltage')

plt.figure(2)
plt.subplots(figsize=(8, 3))
plt.plot(migeum['frequency'][:1000], 'r')
plt.title('migeum_l')
plt.xlabel('timestamp')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
# d_1 = pd.read_csv('/Users/jill/Desktop/migeum.csv', header = None, names = column_names)
# d_2 = pd.read_csv('/Users/jill/Desktop/migeum.csv', header = None, names = column_names)   
# d_3 = pd.read_csv('/Users/jill/Desktop/migeum.csv', header = None, names = column_names)   
# d_4 = pd.read_csv('/Users/jill/Desktop/migeum.csv', header = None, names = column_names)   
# d_5 = pd.read_csv('/Users/jill/Desktop/migeum.csv', header = None, names = column_names)   
# d_6 = pd.read_csv('/Users/jill/Desktop/migeum.csv', header = None, names = column_names)

# %%
fig = plt.figure()
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"

# fig = plt.subplots(1,2, figsize=(15,10))
ax1 = fig.add_subplot(12,2,1)
ax1 = fig.set_figheight(20)
ax1 = fig.set_figwidth(15)
plt.title('branch_trip')
plt.plot(d_1['voltage'][:2405], 'g')
plt.xlabel('timestamp')
plt.ylabel('voltage')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax2 = fig.add_subplot(12,2,2)
plt.title('branch_trip')
plt.plot(d_1['frequency'][:2405], 'r')
plt.xlabel('timestamp')
plt.ylabel('frequency')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax3 = fig.add_subplot(12,2,3)
plt.title('gen_loss')
plt.plot(d_2['voltage'][:2405], 'g')
plt.xlabel('timestamp')
plt.ylabel('voltage')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax4 = fig.add_subplot(12,2,4)
plt.title('gen_loss')
plt.plot(d_2['frequency'][:2405], 'r')
plt.xlabel('timestamp')
plt.ylabel('frequency')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax5 = fig.add_subplot(12,2,5)
plt.title('line_fault')
plt.plot(d_3['voltage'][:2405], 'g')
plt.xlabel('timestamp')
plt.ylabel('voltage')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax6 = fig.add_subplot(12,2,6)
plt.title('line_fault')
plt.plot(d_3['frequency'][:2405], 'r')
plt.xlabel('timestamp')
plt.ylabel('frequency')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax7 = fig.add_subplot(12,2,7)
plt.title('load_loss')
plt.plot(d_4['voltage'][:2405], 'g')
plt.xlabel('timestamp')
plt.ylabel('voltage')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax8 = fig.add_subplot(12,2,8)
plt.title('load_loss')
plt.plot(d_4['frequency'][:2405], 'r')
plt.xlabel('timestamp')
plt.ylabel('frequency')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax9 = fig.add_subplot(12,2,9)
plt.title('shunt_loss')
plt.plot(d_5['voltage'][:2405], 'g')
plt.xlabel('timestamp')
plt.ylabel('voltage')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax10 = fig.add_subplot(12,2,10)
plt.title('shunt_loss')
plt.plot(d_5['frequency'][:2405], 'r')
plt.xlabel('timestamp')
plt.ylabel('frequency')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax11 = fig.add_subplot(12,2,11)
plt.title('vref')
plt.plot(d_6['voltage'][:2405], 'g')
plt.xlabel('timestamp')
plt.ylabel('voltage')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"


ax12 = fig.add_subplot(12,2,12)
plt.title('vref')
plt.plot(d_6['frequency'][:2405], 'r')
plt.xlabel('timestamp')
plt.ylabel('frequency')
plt.tight_layout() # Or equivalently,  "plt.tight_layout()"
